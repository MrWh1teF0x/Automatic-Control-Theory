# %% [markdown]
# ## Задача 5.
#
# На вход системы с передаточной функцией
#
# $$
# W(s) = K_0 \frac{Ts + 1}{s^2}
# $$
#
# поступает:
#
# - Полезный сигнал
#   $$
#   x(t) = at + \frac{bt^2}{2}
#   $$
#
# - Помеха $f(t)$ в виде **белого шума** со спектральной плотностью
#
#   $$
#   S_f(\omega) = N
#   $$
#
# ## Постановка задачи:
#
# Определить **постоянную времени $T$**, при которой **среднеквадратическое отклонение (С.К.О.) суммарной ошибки минимально**.
